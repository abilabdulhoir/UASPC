# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

image = cv2.imread('tes6.jpg')

hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

red_low = np.array([160, 57, 51], np.uint8)
red_high = np.array([180, 255, 255], np.uint8)

green_low = np.array([20, 32, 32], np.uint8)
green_high = np.array([171, 255, 255], np.uint8)

orange_low = np.array([10, 100, 20], np.uint8)  
orange_high = np.array([25, 255, 255], np.uint8) 

red_mask = cv2.inRange(hsv_image, red_low, red_high)
green_mask = cv2.inRange(hsv_image, green_low, green_high)
orange_mask = cv2.inRange(hsv_image, orange_low, orange_high)

kernel = np.ones((70,80), np.uint8)
dilasi_red_mask = cv2.dilate(red_mask, kernel, iterations=1)

kernel = np.ones((5,5), np.uint8)
dilasi_green_mask = cv2.dilate(green_mask, kernel, iterations=1)

kernel = np.ones((5,5), np.uint8)
dilasi_orange_mask = cv2.dilate(orange_mask, kernel, iterations=1)

apel_red = cv2.bitwise_and(image, image, mask=dilasi_red_mask)
alpukat_green = cv2.bitwise_and(image, image, mask=dilasi_green_mask)
jeruk_orange = cv2.bitwise_and(image, image, mask=dilasi_orange_mask)

image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
apel_red = cv2.cvtColor(apel_red, cv2.COLOR_RGB2BGR)
alpukat_green = cv2.cvtColor(alpukat_green, cv2.COLOR_RGB2BGR)
jeruk_orange = cv2.cvtColor(jeruk_orange, cv2.COLOR_RGB2BGR)

fig, axes = plt.subplots(1,4, figsize=(16,8))
ax = axes.ravel()

ax[0].imshow(image)
ax[0].set_title("Gambar Asli")

ax[1].imshow(apel_red)
ax[1].set_title("Apel")

ax[2].imshow(mangga_green)
ax[2].set_title("Alpukat")

ax[3].imshow(jeruk_orange)
ax[3].set_title("Jeruk")
# Out:
# Text(0.5, 1.0, 'Jeruk')
